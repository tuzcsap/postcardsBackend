# %%
import motor.motor_asyncio

# %%
import pprint

# %%
client = motor.motor_asyncio.AsyncIOMotorClient(
    f"mongodb+srv://admin:azc9Gy3ZhU8Ujuea@cluster0.kbeng.mongodb.net/PostcardsDB?retryWrites=true&w=majority")

# %%
db = client.PostcardsDB

# %%
collection = db.PostcardsCollection

# %%
document = {
    'id': '1',
    'url_front': 'Optional[str]',
    'url_back': 'Optional[str]',
    'text': 'Optional[str]',
    'sent_date': 'Optional[str]',
    'received_date': 'Optional[str]',
    'from_address': 'Optional[str]',
    'to_address': 'Optional[str]',
    'lat_from': 'Optional[str]',
    'lon_from': 'Optional[str]',
    'lat_to': 'Optional[str]',
    'lon_to': 'Optional[str]',
    'sender_name': 'Optional[str]',
    'receiver_name': 'Optional[str]',
    'period': 'Optional[str]',
    'tags': 'Optional[List[str]]'
}

# %%
# insert document

# %%
async def insert_document(document):
    result = await collection.insert_one(document)
    print('result %s' % repr(result.inserted_id))
    return result.inserted_id

# %%
await insert_document(document)
# Out:
# result ObjectId('61ab5a72d4b6cc696aae9b1c')
# ObjectId('61ab5a72d4b6cc696aae9b1c')

# %%
# get document by id

# %%
async def get_by_base_id(base_id):
    doc = await collection.find_one({'id': base_id})
    pprint.pprint(doc)

# %%
await get_by_base_id('1')
# Out:
# {'_id': ObjectId('61ab5a72d4b6cc696aae9b1c'),
#  'from_address': 'Optional[str]',
#  'id': '1',
#  'lat_from': 'Optional[str]',
#  'lat_to': 'Optional[str]',
#  'lon_from': 'Optional[str]',
#  'lon_to': 'Optional[str]',
#  'period': 'Optional[str]',
#  'received_date': 'Optional[str]',
#  'receiver_name': 'Optional[str]',
#  'sender_name': 'Optional[str]',
#  'sent_date': 'Optional[str]',
#  'tags': 'Optional[List[str]]',
#  'text': 'Optional[str]',
#  'to_address': 'Optional[str]',
#  'url_back': 'Optional[str]',
#  'url_front': 'Optional[str]'}

# %%
# print(await client.server_info())

# %%
import json

# %%
with open("data/postcards_with_coords.json", "r") as postcards_file:
    postcards_json = json.load(postcards_file)

# %%
postcards_json
# Out:
# [{'id': 51,
#   'Pic_url_1': 'https://forum.vgd.ru/file.php?fid=454522&key=231157345',
#   'Pic_url_2': 'https://forum.vgd.ru/file.php?fid=454521&key=510927720',
#   'Язык текста открытки': 'русский',
#   'Дата написания текста (если автор указал явно, не штампы)': 'xx.xx.xxxx',
#   'Адрес отправителя': 'Москва',
#   'Имя отправителя': 'М.Каневски',
#   'Адрес получателя': 'Ростов на Дону, Летнее помещение коммерческого клуба, Симфонический оркестр Л.П.Штейнберга',
#   'Индекс получателя': '[отсутствует] ',
#   'Имя получателя': 'П. Перов ',
#   'Дата открытки со штампа (место отправления)': 'xx.05.1910',
#   'Дата открытки со штампа (место, куда открытка прибыла)': '06.05.1910',
#   'Период (дореволюционный, советский, постсоветский)': 'Дореволюционные',
#   'Страна (откуда)': 'Российская империя',
#   'Населенный пункт (откуда)': 'Московская губерния, Московский уезд, город Москва',
#   'Страна (куда)': 'Российская империя',
# ...

# %%
len(postcards_json)
# Out:
# 355

# %%
test_json = postcards_json[:10]

# %%
async def insert_document_list(doc_list):
    result = await collection.insert_many(
        doc_list
    )
    return result.inserted_ids

# %%
await insert_document_list(test_json)
# Out:
# [ObjectId('61ab7253d4b6cc696aae9b1d'),
#  ObjectId('61ab7253d4b6cc696aae9b1e'),
#  ObjectId('61ab7253d4b6cc696aae9b1f'),
#  ObjectId('61ab7253d4b6cc696aae9b20'),
#  ObjectId('61ab7253d4b6cc696aae9b21'),
#  ObjectId('61ab7253d4b6cc696aae9b22'),
#  ObjectId('61ab7253d4b6cc696aae9b23'),
#  ObjectId('61ab7253d4b6cc696aae9b24'),
#  ObjectId('61ab7253d4b6cc696aae9b25'),
#  ObjectId('61ab7253d4b6cc696aae9b26')]

# %%
await collection.find().to_list(100)
# Out:
# [{'_id': ObjectId('61ab5a72d4b6cc696aae9b1c'),
#   'id': '1',
#   'url_front': 'Optional[str]',
#   'url_back': 'Optional[str]',
#   'text': 'Optional[str]',
#   'sent_date': 'Optional[str]',
#   'received_date': 'Optional[str]',
#   'from_address': 'Optional[str]',
#   'to_address': 'Optional[str]',
#   'lat_from': 'Optional[str]',
#   'lon_from': 'Optional[str]',
#   'lat_to': 'Optional[str]',
#   'lon_to': 'Optional[str]',
#   'sender_name': 'Optional[str]',
#   'receiver_name': 'Optional[str]',
#   'period': 'Optional[str]',
#   'tags': 'Optional[List[str]]'},
#  {'_id': ObjectId('61ab7253d4b6cc696aae9b1d'),
#   'id': 51,
#   'Pic_url_1': 'https://forum.vgd.ru/file.php?fid=454522&key=231157345',
#   'Pic_url_2': 'https://forum.vgd.ru/file.php?fid=454521&key=510927720',
#   'Язык текста открытки': 'русский',
#   'Дата написания текста (если автор указал явно, не штампы)': 'xx.xx.xxxx',
#   'Адрес отправителя': 'Москва',
#   'Имя отправителя': 'М.Каневски',
# ...
